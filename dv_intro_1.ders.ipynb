# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.1. Install and Import Library

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ayseketen/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt    #mpl de olabilir.

# %% [markdown]
# # 1.2 Matplotlib

# %% [markdown]
# # 1.2.1 Line

# %%
x = np.linspace(0,10,20)
y = 2 * x

# %%
plt.figure(figsize = (10, 6))
plt.plot(x, y)

plt.show()

# %%
plt.figure(figsize = (5, 3))
plt.plot(x, y)

plt.show()

# %% [markdown]
# # 1.2.2 Scatter

# %%
x = np.array([4, 6, 8, 7, 7, 15, 5, 9, 4,
              11, 13, 8, 7, 8 ,11, 9, 12,
              15, 17, 17, 19, 18 ])
y = np.array([89, 76, 77, 78, 101, 76, 93,
             77, 84, 68, 67, 75, 76, 88,
             84, 93, 97, 101, 102, 113, 114, 110])

# %%
plt.figure(figsize = (8, 3))
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ### 1.2.3. Bar Plot

# %%
x = np.array(["A","B","C","D","E"])
y = np.array([5, 11, 3, 14, 8])

# %%
plt.bar(x, y);

# %%
np.random.normal(170, 10, 250)  

#ilk parametre, dağılım ortalama,
#2. standart sapma,
#3.parametre, üretilecek sayı sayısı

# 170 mean, 10 SD (std.sap.), 250 gözlem
# Out:
# array([175.24174968, 166.06817266, 175.54129031, 184.49225509,
#        167.69038014, 175.91109264, 168.6123549 , 167.11476436,
#        173.26167268, 169.16184718, 161.60685153, 174.3126106 ,
#        179.83653092, 162.79035015, 161.08956241, 166.87936153,
#        160.49416458, 168.69720065, 172.50495456, 170.53457957,
#        177.84806675, 155.57545774, 170.18157367, 188.86154414,
#        182.03953651, 154.55014173, 161.62565141, 173.64462717,
#        171.2356288 , 186.49093908, 164.87739721, 174.24671382,
#        161.91916534, 170.95904359, 169.4464199 , 187.21880821,
#        177.20646263, 161.14748211, 158.83486662, 167.64470292,
#        156.22060767, 164.68405796, 178.87250419, 169.76420713,
#        174.31753469, 163.00315661, 153.74083901, 169.866213  ,
#        188.98162553, 178.45697594, 158.48346217, 163.19365168,
#        181.61264371, 155.2467128 , 167.6093614 , 159.34382221,
#        169.79816118, 163.62146676, 179.77171622, 169.69608547,
#        177.63178982, 175.07497748, 173.84974005, 170.6978551 ,
#        168.07772438, 156.80269635, 164.91130293, 155.92133861,
#        161.95875852, 164.80944229, 145.87247423, 175.79462272,
#        170.27972677, 169.94314766, 172.0649772 , 177.25954563,
#        180.8083182 , 163.26197123, 172.6638995 , 174.5197022 ,
#        162.16463955, 174.13623436, 169.80269562, 174.37972916,
#        165.33350852, 165.09321003, 185.59159875, 170.87117627,
#        185.87237592, 169.3782814 , 173.16254558, 174.56245473,
#        152.89809184, 177.63399086, 157.39281433, 157.45434592,
#        176.69320858, 153.24159314, 157.6804333 , 171.0430115 ,
#        177.51121836, 155.80219343, 177.36672554, 171.77635149,
#        182.41828574, 159.46846872, 167.95280857, 183.17579348,
#        160.05528716, 150.09357227, 183.4670726 , 189.9976702 ,
#        186.1014877 , 192.79256008, 164.14382311, 160.0928093 ,
#        157.13138812, 174.23573135, 159.57803869, 174.13190157,
#        157.39475588, 151.68216863, 178.25396114, 152.18423927,
#        182.49999286, 166.33696914, 156.73056877, 179.47929804,
#        169.98285345, 167.34192321, 162.69619617, 185.70075723,
#        189.46440471, 167.06919984, 169.17596551, 174.38634639,
#        158.6583608 , 179.97766154, 160.00637485, 161.7317466 ,
#        169.59543832, 159.94056617, 174.07780658, 179.46762598,
#        177.63347542, 149.35047964, 174.52469293, 172.13936954,
#        152.3627054 , 152.00907355, 176.01403362, 164.23494936,
#        173.95965369, 170.88816068, 169.69140803, 170.91997631,
#        177.82347956, 164.42020541, 172.33582153, 173.07232421,
#        183.76421202, 172.52237964, 166.62619874, 136.6788899 ,
#        161.14927809, 164.44387983, 171.12538061, 164.66364752,
#        163.30291544, 175.5162224 , 169.87008861, 176.0212528 ,
#        166.47888112, 172.25040077, 181.51375882, 164.54519425,
#        166.93420779, 173.20690518, 163.67954709, 170.24556712,
#        164.90141739, 188.62496724, 177.02510267, 166.27986217,
#        167.13696756, 175.12712809, 185.17437127, 156.84025603,
#        174.13786223, 183.94377308, 190.38674964, 161.40317415,
#        161.01178597, 175.33288518, 164.52582142, 163.18737486,
#        169.12508491, 173.33762419, 182.63992631, 162.1000076 ,
#        147.75697443, 167.17785793, 168.32638473, 159.76534235,
#        162.98821526, 146.16946126, 158.76710289, 198.87719123,
#        167.90156089, 177.66063637, 154.78664801, 151.61807669,
#        173.75574734, 171.63198457, 150.4637814 , 155.17828842,
#        177.16746273, 157.08250579, 147.56487368, 173.8134739 ,
#        164.19124865, 166.6876515 , 177.96723844, 161.63217004,
#        200.68103327, 161.80126859, 164.50229939, 166.9709522 ,
#        178.73771152, 164.19440689, 174.76089416, 181.19262532,
#        182.2139242 , 157.1858998 , 168.61468572, 175.80804206,
#        155.88118567, 194.15042111, 187.08866059, 178.20973748,
#        161.91044137, 188.97009072, 173.58851136, 169.73002738,
#        160.31459245, 162.78315234, 165.12399567, 175.92325963,
#        153.98381817, 174.6359853 ])

# %%
plt.hist(x);

# %% [markdown]
# # Boxplot

# %%
x = np.random.normal(170, 10, 250)

# %%
plt.figure(figsize= (10, 6))
plt.boxplot(x);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pie chart

# %%
x = ['Kategori 1', 'Kategori 2', 'Kategori 3', 'Kategori 4']
sizes = [15, 30, 45, 10]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=x)
plt.axis('equal')
plt.show()
